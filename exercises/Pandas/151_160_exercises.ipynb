# %% [markdown]
# <a href="https://colab.research.google.com/github/Cedrik-Black/Data_science/blob/master/exercises/Pandas/151_160_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
#
# ### Spis treści:
# * [Import biblioteki](#0)
# * [Ćwiczenie 151](#1)
# * [Ćwiczenie 152](#2)
# * [Ćwiczenie 153](#3)
# * [Ćwiczenie 154](#4)
# * [Ćwiczenie 155](#5)
# * [Ćwiczenie 156](#6)
# * [Ćwiczenie 157](#7)
# * [Ćwiczenie 158](#8)
# * [Ćwiczenie 159](#9)
# * [Ćwiczenie 160](#10)

# %% [markdown]
# ### <a name='0'></a>Import biblioteki

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
np.__version__
# Out:
# '1.25.2'

# %% [markdown]
# ### <a name='1'></a> Ćwiczenie 151
# Podany jest poniższy obiekt _DataFrame:_
#
# ```
# df = pd.DataFrame(np.random.rand(10, 4), columns=list('ABCD'))
# ```

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0  0.807440  0.896091  0.318003  0.110052
# 1  0.227935  0.427108  0.818015  0.860731
# 2  0.006952  0.510747  0.417411  0.222108
# 3  0.119865  0.337615  0.942910  0.323203
# 4  0.518791  0.703019  0.363630  0.971782
# 5  0.962447  0.251782  0.497249  0.300878
# 6  0.284840  0.036887  0.609564  0.502679
# 7  0.051479  0.278646  0.908266  0.239562
# 8  0.144895  0.489453  0.985650  0.242055
# 9  0.672136  0.761620  0.237638  0.728216

# %% [markdown]
# Wytnij wiersze obiektu _df_ dla których kolumna _C_ jest większa niż 0.8.
# Pomocniczo: Analogicznie jak w jezyku SQL poniższe zapytanie:
#
#
# ```
# SELECT * FROM df WHERE C > 0.8
# ```

# %%
df[df['C'] > 0.8]
# Out:
#           A         B         C         D
# 1  0.227935  0.427108  0.818015  0.860731
# 3  0.119865  0.337615  0.942910  0.323203
# 7  0.051479  0.278646  0.908266  0.239562
# 8  0.144895  0.489453  0.985650  0.242055

# %% [markdown]
# ### <a name='2'></a> Ćwiczenie 152
#
# Wytnij wiersze obiektu _df_ dla których kolumna _C_ jest większa niż 0.3 oraz kolumna _D_ jest mniejsza niż 0.7.

# %%
df[(df['C'] > 0.3) & (df['D'] < 0.7)]
# Out:
#           A         B         C         D
# 0  0.807440  0.896091  0.318003  0.110052
# 2  0.006952  0.510747  0.417411  0.222108
# 3  0.119865  0.337615  0.942910  0.323203
# 5  0.962447  0.251782  0.497249  0.300878
# 6  0.284840  0.036887  0.609564  0.502679
# 7  0.051479  0.278646  0.908266  0.239562
# 8  0.144895  0.489453  0.985650  0.242055

# %% [markdown]
# ### <a name='3'></a> Ćwiczenie 153
# Dokonaj iteracji po pierwszych pięciu wierszach obiektu _df_. Każdy wiersz wydrukuj do konsoli.
#
# __Wskazówka:__ Wykorzystaj funkcję _pd.DataFrame.iterrows()_.

# %%
for index, row in df.head().iterrows():
  print(row)
# Out:
# A    0.807440
# B    0.896091
# C    0.318003
# D    0.110052
# Name: 0, dtype: float64
# A    0.227935
# B    0.427108
# C    0.818015
# D    0.860731
# Name: 1, dtype: float64
# A    0.006952
# B    0.510747
# C    0.417411
# D    0.222108
# Name: 2, dtype: float64
# A    0.119865
# B    0.337615
# C    0.942910
# D    0.323203
# Name: 3, dtype: float64
# A    0.518791
# B    0.703019
# C    0.363630
# D    0.971782
# Name: 4, dtype: float64

# %% [markdown]
# ### <a name='4'></a> Ćwiczenie 154
# Ustaw wartość w wierszu o indeksie 3 dla kolumny B jako _np.nan_.
# Wykorzystaj _df.iloc_.

# %%
df['B'].iloc[3] = np.nan

# %% [markdown]
# Ustaw wartość w wierszu o indeksie 8 dla kolumny D jako _np.nan_. Wykorzystaj _df.loc_.

# %%
df.loc[8, 'D'] = np.nan

# %% [markdown]
# Wyświetl obiekt _df_.

# %%
df
# Out:
#           A         B         C         D
# 0  0.807440  0.896091  0.318003  0.110052
# 1  0.227935  0.427108  0.818015  0.860731
# 2  0.006952  0.510747  0.417411  0.222108
# 3  0.119865       NaN  0.942910  0.323203
# 4  0.518791  0.703019  0.363630  0.971782
# 5  0.962447  0.251782  0.497249  0.300878
# 6  0.284840  0.036887  0.609564  0.502679
# 7  0.051479  0.278646  0.908266  0.239562
# 8  0.144895  0.489453  0.985650       NaN
# 9  0.672136  0.761620  0.237638  0.728216

# %% [markdown]
# ### <a name='5'></a> Ćwiczenie 155
# Usuń wszystkie wiersze z obiektu _df_ zawierające braki danych i przypisz do zmiennej _df1_. Wyświetl zmienną _df1_.

# %%
df1 = df.dropna()
df1
# Out:
#           A         B         C         D
# 0  0.863103  0.623298  0.330898  0.063558
# 1  0.310982  0.325183  0.729606  0.637557
# 2  0.887213  0.472215  0.119594  0.713245
# 4  0.522733  0.427541  0.025419  0.107891
# 5  0.031429  0.636410  0.314356  0.508571
# 6  0.907566  0.249292  0.410383  0.755551
# 7  0.228798  0.076980  0.289751  0.161221
# 9  0.803672  0.186570  0.892559  0.539342

# %% [markdown]
# ### <a name='6'></a> Ćwiczenie 156
# Zauważ, że indeks po usunięciu dwóch wieszy w obiekcie _df1_ nie jest po kolei. Zresetuj indeks, aby wprowadzić kolejność (nie dodawaj nowej kolumny, tylko zreseuj indeks). Wyświetl zmienną _df1_.

# %%
df1 = df1.reset_index(drop=True)
df1
# Out:
#           A         B         C         D
# 0  0.863103  0.623298  0.330898  0.063558
# 1  0.310982  0.325183  0.729606  0.637557
# 2  0.887213  0.472215  0.119594  0.713245
# 3  0.522733  0.427541  0.025419  0.107891
# 4  0.031429  0.636410  0.314356  0.508571
# 5  0.907566  0.249292  0.410383  0.755551
# 6  0.228798  0.076980  0.289751  0.161221
# 7  0.803672  0.186570  0.892559  0.539342

# %% [markdown]
# ### <a name='7'></a> Ćwiczenie 157
# Wracamy do obiektu _df_. Wyznacz liczbę brakujących elementów w obiekcie _df_ dla każdej kolumny.

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    0
# D    1
# dtype: int64

# %% [markdown]
# ### <a name='8'></a> Ćwiczenie 158
# Uzupełnij brakujące wartości wartością 0 i przypisz do zmiennej _df_.

# %%
df = df.fillna(0)
df
# Out:
#           A         B         C         D
# 0  0.807440  0.896091  0.318003  0.110052
# 1  0.227935  0.427108  0.818015  0.860731
# 2  0.006952  0.510747  0.417411  0.222108
# 3  0.119865  0.000000  0.942910  0.323203
# 4  0.518791  0.703019  0.363630  0.971782
# 5  0.962447  0.251782  0.497249  0.300878
# 6  0.284840  0.036887  0.609564  0.502679
# 7  0.051479  0.278646  0.908266  0.239562
# 8  0.144895  0.489453  0.985650  0.000000
# 9  0.672136  0.761620  0.237638  0.728216

# %% [markdown]
# ### <a name='9'></a> Ćwiczenie 159
# Zamień kolejność kolumn w obiekcie _df_ na podaną poniżej:
# * D, A, B, C
#
# i przypisz do zmiennej _df_.

# %%
df = df[['D', 'A', 'B', 'C']]
df
# Out:
#           D         A         B         C
# 0  0.110052  0.807440  0.896091  0.318003
# 1  0.860731  0.227935  0.427108  0.818015
# 2  0.222108  0.006952  0.510747  0.417411
# 3  0.323203  0.119865  0.000000  0.942910
# 4  0.971782  0.518791  0.703019  0.363630
# 5  0.300878  0.962447  0.251782  0.497249
# 6  0.502679  0.284840  0.036887  0.609564
# 7  0.239562  0.051479  0.278646  0.908266
# 8  0.000000  0.144895  0.489453  0.985650
# 9  0.728216  0.672136  0.761620  0.237638

# %% [markdown]
# ### <a name='10'></a> Ćwiczenie 160
# Usuń kolumnę $D$ z obiektu _df_.

# %%
del df['D']
df
# Out:
#           A         B         C
# 0  0.807440  0.896091  0.318003
# 1  0.227935  0.427108  0.818015
# 2  0.006952  0.510747  0.417411
# 3  0.119865  0.000000  0.942910
# 4  0.518791  0.703019  0.363630
# 5  0.962447  0.251782  0.497249
# 6  0.284840  0.036887  0.609564
# 7  0.051479  0.278646  0.908266
# 8  0.144895  0.489453  0.985650
# 9  0.672136  0.761620  0.237638
